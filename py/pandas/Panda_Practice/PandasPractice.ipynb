# %%
# import module
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# read csv file
df = pd.read_csv(r"C:\Users\Gustavocolmenares\Documents\SchoolStaff\GIS_PCC\Courses_Training\Geo_python_Course\py\pandas\1_intro\nyc_weather.csv")
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
# See the first 5 rows of the data
# use head() function
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
# Return information of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
# EST                     31 non-null object
# Temperature             31 non-null int64
# DewPoint                31 non-null int64
# Humidity                31 non-null int64
# Sea Level PressureIn    31 non-null float64
# VisibilityMiles         31 non-null int64
# WindSpeedMPH            28 non-null float64
# PrecipitationIn         31 non-null object
# CloudCover              31 non-null int64
# Events                  9 non-null object
# WindDirDegrees          31 non-null int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 2.7+ KB

# %%
# number of observation in the dataset
# use .shape 
rows, columns = df.shape
rows, columns
# Out:
# (31, 11)

# %%
# print the number of columns
columns
# Out:
# 11

# %%
# What's the name of column 4
# use .columns[<column_index>] to find the name of the column

df.columns[4]
# Out:
# 'Sea Level PressureIn'

# %%
# print the data type of 'Humidity' column 
df.dtypes['Humidity']
# Out:
# dtype('int64')

# %%
# print the Dataframe indexed
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
# print the values of row 29
df.loc[29]
# Out:
# EST                     1/30/2016
# Temperature                    34
# DewPoint                       16
# Humidity                       46
# Sea Level PressureIn        30.01
# VisibilityMiles                10
# WindSpeedMPH                    7
# PrecipitationIn                 0
# CloudCover                      0
# Events                        NaN
# WindDirDegrees                257
# Name: 29, dtype: object

# %%
# Get the value from the row 29 - column 4
# .values[<index_row>][index_column] return the value of that cell

df.values[29][4]
# Out:
# 30.01

# %%
# Set a column as Index using .st_index(), will change index temporately
# <dataframe>.set_index(<index_range>, inplace=True), for permanently change index 
# <dataframe>.reset_index(inplace=True), to reset index

dates = df.set_index('EST')
#dates[:25] # or you can use <dataframe>.head(<index_number>)
dates.head(25)
# Out:
#            Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/1/2016            38        23        52                 30.03
# 1/2/2016            36        18        46                 30.02
# 1/3/2016            40        21        47                 29.86
# 1/4/2016            25         9        44                 30.05
# 1/5/2016            20        -3        41                 30.57
# 1/6/2016            33         4        35                 30.50
# 1/7/2016            39        11        33                 30.28
# 1/8/2016            39        29        64                 30.20
# 1/9/2016            44        38        77                 30.16
# 1/10/2016           50        46        71                 29.59
# 1/11/2016           33         8        37                 29.92
# 1/12/2016           35        15        53                 29.85
# 1/13/2016           26         4        42                 29.94
# ...

# %%
# See the last 10 rows using <dataframe>.tail(<index_number>)
dates.tail(10)
# Out:
#            Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/22/2016           26         6        41                 30.21
# 1/23/2016           26        21        78                 29.77
# 1/24/2016           28        11        53                 29.92
# 1/25/2016           34        18        54                 30.25
# 1/26/2016           43        29        56                 30.03
# 1/27/2016           41        22        45                 30.03
# 1/28/2016           37        20        51                 29.90
# 1/29/2016           36        21        50                 29.58
# 1/30/2016           34        16        46                 30.01
# 1/31/2016           46        28        52                 29.90
#
#            VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover  \
# EST
# 1/22/2016                9           NaN            0.01           3
# 1/23/2016                1          16.0            2.31           8
# ...

# %%
# Numbers of rows in the dataset
df.shape[0]
# Out:
# 31

# %%
# number of columns in the dataset
df.shape[1]
# Out:
# 11

# %%
# print name of columns 
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
# # print the dataframe index
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
# print data type of columns use  <dataframe>.dtypes
dates.dtypes
# Out:
# Temperature               int64
# DewPoint                  int64
# Humidity                  int64
# Sea Level PressureIn    float64
# VisibilityMiles           int64
# WindSpeedMPH            float64
# PrecipitationIn          object
# CloudCover                int64
# Events                   object
# WindDirDegrees            int64
# dtype: object

# %%
# print the Tempearature column
df.Temperature # or df['Temperature]
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
# obtain the count for unique values in the 'Temperature' column 
# use <dataframe>.<column>.nunique()
df.Temperature.nunique()
# Out:
# 22

# %%
df.Temperature.nunique()
# Out:
# 22

# %%
df.Temperature.plot()
